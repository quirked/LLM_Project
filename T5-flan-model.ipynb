# %%
# !pip -q install langchain tiktoken chromadb pypdf InstructorEmbedding
# !pip install transformers==4.30
# !pip -q install accelerate bitsandbytes kaleido openai cohere python-multipart

# %%
# !pip show langchain

# %% [markdown]
# ## QA Retrieval No Open AI - Flan-T5-XL

# %%
# !pip install torch
import torch
import transformers
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-xl")

# %%
# del tokenizer,model

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-xl",
                                              load_in_8bit=True,
                                              device_map='auto',
                                              # torch_dtype=torch.float16,
                                              low_cpu_mem_usage=True,

                                              )

# %%
from transformers import pipeline
from langchain.llms import HuggingFacePipeline
import torch

pipe = pipeline(
    "text2text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=512,
    temperature=0,
    top_p=0.95,
    repetition_penalty=1.15
)

local_llm = HuggingFacePipeline(pipeline=pipe)

# %% [markdown]
# #### Check the LLM is working

# %%
print(local_llm('What is the capital of Great Britain?'))

# %% [markdown]
# # LangChain multi-doc retriever with ChromaDB
#
# ***New Points***
# - Multiple Files - PDFs
# - ChromaDB
# - Local LLM
# - Instuctor Embeddings

# %% [markdown]
# ## Setting up LangChain

# %%
import os
# !pip install sentence_transformers

from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter

from langchain.chains import RetrievalQA
from langchain.document_loaders import TextLoader
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import DirectoryLoader


from InstructorEmbedding import INSTRUCTOR
from langchain.embeddings import HuggingFaceInstructEmbeddings

# %% [markdown]
# ## Load multiple and process documents

# %%
# Load and process the text files
# loader = TextLoader('single_text_file.pdf')
loader = DirectoryLoader('/kaggle/input/dataset', glob="./*.pdf", loader_cls=PyPDFLoader)

documents = loader.load()

# %%
len(documents)

# %%
#splitting the text into
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
texts = text_splitter.split_documents(documents)

# %%
len(texts)

# %% [markdown]
# ## HF Instructor Embeddings

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings

instructor_embeddings = HuggingFaceInstructEmbeddings(model_name="hkunlp/instructor-xl",
                                                      model_kwargs={"device": "cuda"})

# %% [markdown]
# ## create the DB

# %%
# !pip install faiss-gpu

# %%
# Embed and store the texts
# Supplying a persist_directory will store the embeddings on disk
# persist_directory = '/kaggle/input/database'

# ## Here is the nmew embeddings being used
embedding = instructor_embeddings



from langchain.vectorstores import FAISS
db = FAISS.from_documents(texts, embedding)
# vectordb = Chroma.from_documents(texts,
#                                  embedding,
#                                  persist_directory=persist_directory)

# %% [markdown]
# ## Make a retriever

# %%
retriever = db.as_retriever(search_kwargs={"k": 2})

# %% [markdown]
# ## Make a chain

# %%
# create the chain to answer questions
qa_chain = RetrievalQA.from_chain_type(llm=local_llm,
                                  chain_type="stuff",
                                  retriever=retriever,
                                  return_source_documents=True)

# %%
## Cite sources

import textwrap

def wrap_text_preserve_newlines(text, width=110):
    # Split the input text into lines based on newline characters
    lines = text.split('\n')

    # Wrap each line individually
    wrapped_lines = [textwrap.fill(line, width=width) for line in lines]

    # Join the wrapped lines back together using newline characters
    wrapped_text = '\n'.join(wrapped_lines)

    return wrapped_text

def process_llm_response(llm_response):
    print(wrap_text_preserve_newlines(llm_response['result']))
    print('\n\nSources:')
    for source in llm_response["source_documents"]:
        print(source.metadata['source'])

# %%
# !pip install pandas openpyxl

# %%
import os
import pandas as pd

# %%
# Define the directory where you want to save the file
save_directory = '/kaggle/working/'

# List to store query-response pairs
data = []

queries = []
standard_answers = []
batch_size = 19  # Adjust the batch size as needed

while True:
    query = input("Enter your query (or type 'process' to process the queries): ")
    if query == 'process':
        if queries:
            llm_responses = [qa_chain(q) for q in queries]
            for query, response, standard_answer in zip(queries, llm_responses, standard_answers):
                # Extract only the 'result' part of the response
                response_text = response.get('result', 'No response found')
                print(f"Query: {query}\nProcessed response: {response_text}\nStandard Answer: {standard_answer}\n")  # Print the query, processed response, and standard answer
                # Store the query, the response text, and the standard answer
                data.append({"Query": query, "Response": response_text, "Standard Answer": standard_answer})
            queries = []  # Reset the queries list
            standard_answers = []  # Reset the standard answers list
        else:
            print("No queries to process.")
    elif query == 'exit':
        # Create DataFrame and write to Excel file before exiting
        df = pd.DataFrame(data)
        file_path = os.path.join(save_directory, "queries_and_responses.xlsx")
        
        df.to_excel(file_path, index=False)
        print(f"Excel file saved at {file_path}. Exiting.")
        break
    elif len(queries) < batch_size:
        queries.append(query)
        standard_answer = input("Enter the standard answer for this query: ")
        standard_answers.append(standard_answer)
    else:
        print(f"Processing {batch_size} queries...")
        llm_responses = [qa_chain(q) for q in queries]
        for query, response, standard_answer in zip(queries, llm_responses, standard_answers):
            # Extract only the 'result' part of the response
            response_text = response.get('result', 'No response found')
            print(f"Query: {query}\nProcessed response: {response_text}\nStandard Answer: {standard_answer}\n")  # Print the query, processed response, and standard answer
            # Store the query, the response text, and the standard answer
            data.append({"Query": query, "Response": response_text, "Standard Answer": standard_answer})
        queries = []  # Reset the queries list
        standard_answers = []  # Reset the standard answers list
# Out:
# Enter your query (or type 'process' to process the queries):  What is the purpose of the Indian Network of Climate Change Assessment (INCCA)?
# Enter the standard answer for this query:  To assess the drivers and implications of climate change through scientific research and prepare climate change assessments.
# Enter your query (or type 'process' to process the queries):  How does the IPCC characterize the impact of human activities on climate?
# Enter the standard answer for this query:  The impact of human activities on climate is unequivocal (IPCC, 2007).
# Enter your query (or type 'process' to process the queries):  Which social and economic sectors in India were assessed for climate change impacts in the 2050s and 2080s?
# Enter the standard answer for this query:  Water resources, agriculture, natural ecosystems and forestry, human health, infrastructure, and energy.
# Enter your query (or type 'process' to process the queries):  What regions in India are considered climate-sensitive in the assessment?
# Enter the standard answer for this query:  Himalayan region, North-Eastern region, Western Ghats, and Coastal region
# Enter your query (or type 'process' to process the queries):  What institutions are involved in the Indian Network of Climate Change Assessment (INCCA)?
# Enter the standard answer for this query:  Various ministries, research institutions, and NGOs, including the Ministry of Environment and Forests, Indian Space Research Organisation, and Indian Institute of Technology.
# Enter your query (or type 'process' to process the queries):  How are climate change scenarios derived in the assessment?
# Enter the standard answer for this query:  Climate change scenarios are derived from the regional climate change model PRECIS, forced by a greenhouse gas emission scenario (A1B IPCC SRES).
# Enter your query (or type 'process' to process the queries):  What is the time frame for the 2030s in the context of climate change scenarios?
# Enter the standard answer for this query:  The 2030s represent the average of the period between 2021 to 2050
# Enter your query (or type 'process' to process the queries):  How is sea-level rise projected along the Indian coastline?
# Enter the standard answer for this query:  Sea-level rise projection along the Indian coastline aligns with global projections from the IPCC Fourth Assessment Report.
# Enter your query (or type 'process' to process the queries):  Which simulation model was used to assess the impact on agriculture productivity?
# Enter the standard answer for this query:  InfoCrop was used to assess the impact on the productivity of cereals and coconut plantations
# Enter your query (or type 'process' to process the queries):  What are the key sectors of the economy assessed for climate change impacts in the 2030s?
# Enter the standard answer for this query:  Agriculture, water, natural ecosystems and biodiversity, and human health.
# Enter your query (or type 'process' to process the queries):  Why was no assessment using the crop model carried out for the Himalayan region?
# Enter the standard answer for this query:  Due to the lack of required climate data at a 1o x1o scale.
# Enter your query (or type 'process' to process the queries):  How are impacts on livestock productivity analyzed in the assessment?
# Enter the standard answer for this query:  Analysis is based on temperature and humidity projections from PRECIS for the 2030s.
# Enter your query (or type 'process' to process the queries):  What methodology is used to assess natural ecosystems and biodiversity?
# Enter the standard answer for this query:  The assessment is mainly based on a review of available literature and the use of a dynamic vegetation model IBIS.
# Enter your query (or type 'process' to process the queries):  What parameters are required by IBIS for assessing forest vegetation and Net Primary Productivity?
# Enter the standard answer for this query:  Monthly temperature, precipitation, relative humidity, wind speed, cloudiness, and soil texture.
# Enter your query (or type 'process' to process the queries):  How are the impacts of climate change on human health assessed qualitatively?
# Enter the standard answer for this query:  The likely impact on morbidity and mortality due to extreme temperatures, flooding, melting glaciers, and sea-level rise.
# Enter your query (or type 'process' to process the queries):  Which tool is used to simulate runoff in the river basins for the water analysis?
# Enter the standard answer for this query:  SWAT (Soil and Water Assessment Tool) is used for simulation.
# Enter your query (or type 'process' to process the queries):  How does the assessment contribute to adaptation strategies?
# Enter the standard answer for this query:  Short-term assessments like those for the 2030s help develop adaptation strategies for a foreseeable future
# Enter your query (or type 'process' to process the queries):  What is the significance of the Minister for Environment & Forests launching INCCA in 2009?
# Enter the standard answer for this query:  It aims to enhance knowledge about the impacts of climate change at the national and subnational levels.
# Enter your query (or type 'process' to process the queries):  What are the four major climate-sensitive regions in India discussed in the assessment?
# Enter the standard answer for this query:  : Himalayan region, North-Eastern region, Western Ghats, and Coastal region.
# Enter your query (or type 'process' to process the queries):  How does the report address the impacts of climate variability in India?
# Processing 19 queries...
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Query: What is the purpose of the Indian Network of Climate Change Assessment (INCCA)?
# Processed response: to assess the drivers and implications of climate change through scientifi c research
# Standard Answer: To assess the drivers and implications of climate change through scientific research and prepare climate change assessments.
#
# Query: How does the IPCC characterize the impact of human activities on climate?
# Processed response: unequivocal
# Standard Answer: The impact of human activities on climate is unequivocal (IPCC, 2007).
#
# Query: Which social and economic sectors in India were assessed for climate change impacts in the 2050s and 2080s?
# Processed response: Agriculture, Water, Natural Ecosystems and Biodiversity and Human Health
# Standard Answer: Water resources, agriculture, natural ecosystems and forestry, human health, infrastructure, and energy.
#
# Query: What regions in India are considered climate-sensitive in the assessment?
# Processed response: the Himalayan region, the North-Eastern region, the Western Ghats and the Coastal region
# Standard Answer: Himalayan region, North-Eastern region, Western Ghats, and Coastal region
#
# Query: What institutions are involved in the Indian Network of Climate Change Assessment (INCCA)?
# Processed response: MoEF , Ministry of Earth Sciences, Ministry of Agriculture, Ministry of Science &Technology, Defence Research and Development Organisation etc., along with research institutions
# Standard Answer: Various ministries, research institutions, and NGOs, including the Ministry of Environment and Forests, Indian Space Research Organisation, and Indian Institute of Technology.
#
# Query: How are climate change scenarios derived in the assessment?
# Processed response: from a regional climate change model PRECIS
# Standard Answer: Climate change scenarios are derived from the regional climate change model PRECIS, forced by a greenhouse gas emission scenario (A1B IPCC SRES).
#
# Query: What is the time frame for the 2030s in the context of climate change scenarios?
# Processed response: 2021 to 2050
# Standard Answer: The 2030s represent the average of the period between 2021 to 2050
#
# Query: How is sea-level rise projected along the Indian coastline?
# Processed response: in sync with the global projections as assessed in the IPCC Fourth Assessment Report
# Standard Answer: Sea-level rise projection along the Indian coastline aligns with global projections from the IPCC Fourth Assessment Report.
#
# Query: Which simulation model was used to assess the impact on agriculture productivity?
# Processed response: IBIS model
# Standard Answer: InfoCrop was used to assess the impact on the productivity of cereals and coconut plantations
#
# Query: What are the key sectors of the economy assessed for climate change impacts in the 2030s?
# Processed response: Agriculture, Water, Natural Ecosystems and Biodiversity and Human Health
# Standard Answer: Agriculture, water, natural ecosystems and biodiversity, and human health.
#
# Query: Why was no assessment using the crop model carried out for the Himalayan region?
# Processed response: not enough information
# Standard Answer: Due to the lack of required climate data at a 1o x1o scale.
#
# Query: How are impacts on livestock productivity analyzed in the assessment?
# Processed response: temperature and humidity projections from PRECIS
# Standard Answer: Analysis is based on temperature and humidity projections from PRECIS for the 2030s.
#
# Query: What methodology is used to assess natural ecosystems and biodiversity?
# Processed response: review of available literature
# Standard Answer: The assessment is mainly based on a review of available literature and the use of a dynamic vegetation model IBIS.
#
# Query: What parameters are required by IBIS for assessing forest vegetation and Net Primary Productivity?
# Processed response: soil, water and climate parameters
# Standard Answer: Monthly temperature, precipitation, relative humidity, wind speed, cloudiness, and soil texture.
#
# Query: How are the impacts of climate change on human health assessed qualitatively?
# Processed response: likely impact of climate change on morbidity and mortality due to changes in extreme temperatures, fl ooding due to extreme precipitation, melting of glaciers, and sea level rise
# Standard Answer: The likely impact on morbidity and mortality due to extreme temperatures, flooding, melting glaciers, and sea-level rise.
#
# Query: Which tool is used to simulate runoff in the river basins for the water analysis?
# Processed response: SWAT model
# Standard Answer: SWAT (Soil and Water Assessment Tool) is used for simulation.
#
# Query: How does the assessment contribute to adaptation strategies?
# Processed response: The qualitative approach describes the likely impact of climate change on morbidity and mortality due to changes in extreme temperatures, fl ooding due to extreme precipitation, melting of glaciers, and sea level rise
# Standard Answer: Short-term assessments like those for the 2030s help develop adaptation strategies for a foreseeable future
#
# Query: What is the significance of the Minister for Environment & Forests launching INCCA in 2009?
# Processed response: To enhance knowledge about the impacts of climate change at the national and sub national level
# Standard Answer: It aims to enhance knowledge about the impacts of climate change at the national and subnational levels.
#
# Query: What are the four major climate-sensitive regions in India discussed in the assessment?
# Processed response: the Himalayan region, the North-Eastern region, the Western Ghats and the Coastal region
# Standard Answer: : Himalayan region, North-Eastern region, Western Ghats, and Coastal region.
# Enter your query (or type 'process' to process the queries):  How does the report address the impacts of climate variability in India?
# Enter the standard answer for this query:  The report reviews the impacts of climate variability in the four major climate-sensitive regions
# Enter your query (or type 'process' to process the queries):  What is the resolution of the regional climate change model PRECIS used in the assessment?
# Enter the standard answer for this query:  The resolution is 50km x 50km.
# Enter your query (or type 'process' to process the queries):  How is the transmission of malaria assessed in the 2030s?
# Enter the standard answer for this query:  : Transmission windows are defined in terms of temperature and relative humidity
# Enter your query (or type 'process' to process the queries):  Why is sea-level rise expected to continue even if GHG emissions are halted today?
# Enter the standard answer for this query:  The ocean has a significant thermal inertia, leading to a delayed adjustment in sea level.
# Enter your query (or type 'process' to process the queries):  How does INCCA contribute to building capacity for managing climate-change-related risks?
# Enter the standard answer for this query:  : INCCA is designed to build capacity through scientific research, decision support systems, and engagement with knowledge institutions
# Enter your query (or type 'process' to process the queries):  Which sectors were assessed in India's Initial National Communication to the UNFCCC?
# Enter the standard answer for this query:  Water resources, agriculture, natural ecosystems and forestry, human health, infrastructure, and energy.
# Enter your query (or type 'process' to process the queries):  What are the key features of INCCA's programs, as shown in Figure ES1?
# Enter the standard answer for this query:  Assessing drivers and implications of climate change, preparing climate change assessments, developing decision support systems, and building capacity.
# Enter your query (or type 'process' to process the queries):  What is the role of institutions like ISRO and CSIR in studying climate change in India?
# Enter the standard answer for this query:  These institutions, along with others, are working on various studies on climate change in collaboration with the Ministry of Environment and Forests.
# Enter your query (or type 'process' to process the queries):  How is livestock productivity impacted by climate change in the assessment?
# Enter the standard answer for this query:  The analysis is based on temperature and humidity projections, estimating the temperature–humidity index related to animal stress.
# Enter your query (or type 'process' to process the queries):  What regions are considered in the assessment for the impact on fisheries?
# Enter the standard answer for this query:  The impact on coastal fisheries is considered in the Western Ghats, North-Eastern region, and Coastal regions.
# Enter your query (or type 'process' to process the queries):  What is the baseline period for assessing changes in the 2030s?
# Enter the standard answer for this query:  The baseline period is the average of 1961 to 1990s, also referred to as the 1970s.
# Enter your query (or type 'process' to process the queries):  Why is impact assessment research considered a complex challenge?
# Enter the standard answer for this query:  It includes physical, biological, and socio-economic aspects, requiring evolving tools for scientific rigor.
# Enter your query (or type 'process' to process the queries):  What is the climatological diversity of India and how does it complicate the assessment?
# Enter the standard answer for this query:  India's diverse climate, characterized by subregional features, challenges region demarcation due to seamless merging
# Enter your query (or type 'process' to process the queries):  What challenges arise in demarcating the coastal region for assessment purposes?
# Enter the standard answer for this query:  Defining the coastal zone, covering 5,500km along the mainland and 20,000km along islands, poses a significant challenge
# Enter your query (or type 'process' to process the queries):  What are the uncertainties in modeling and data gaps highlighted in the assessment?
# Enter the standard answer for this query:  Inherent uncertainties include assumptions about future population, socio-economic factors, and technical changes, leading to uncertainties in emissions and modeling processes.
# Enter your query (or type 'process' to process the queries):  Why is a higher resolution model suggested for capturing regional details in India?
# Enter the standard answer for this query:  To capture fine-scale details in specific regions like inner Himalayan valleys, higher resolution models (at least 25km x 25km) are deemed more appropriate.
# Enter your query (or type 'process' to process the queries):  How do observations from satellite measurements differ from IPCC model projections in terms of sea-level rise?
# Enter the standard answer for this query:  Observations show a faster sea-level rise (3.4 mm/year) than the IPCC model projection (1.9 mm/year), attributed to the response of continental ice to greenhouse warming.
# Enter your query (or type 'process' to process the queries):  What limitations are associated with the InfoCrop model used for assessing agriculture productivity?
# Enter the standard answer for this query:  The model doesn't consider socio-economic trends, technological improvements, and pests/disease scenarios, impacting the comprehensive assessment of agriculture.
# Enter your query (or type 'process' to process the queries):  Why does the IBIS model used for assessing changes in vegetation require a long-term observational plan?
# Enter the standard answer for this query:  The model's accuracy is limited due to the lack of an extensive finely gridded database on soil, water, climate, and vegetation types.
# Enter your query (or type 'process' to process the queries):  What challenges are associated with the SWAT model used for assessing water yields in various regions?
# Processing 19 queries...
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Query: How does the report address the impacts of climate variability in India?
# Processed response: It presents an assessment of the impacts of climate change in the 2030s on four key sectors of the economy that are climate dependent
# Standard Answer: The report reviews the impacts of climate variability in the four major climate-sensitive regions
#
# Query: What is the resolution of the regional climate change model PRECIS used in the assessment?
# Processed response: 50km x 50km
# Standard Answer: The resolution is 50km x 50km.
#
# Query: How is the transmission of malaria assessed in the 2030s?
# Processed response: based on temperature
# Standard Answer: : Transmission windows are defined in terms of temperature and relative humidity
#
# Query: Why is sea-level rise expected to continue even if GHG emissions are halted today?
# Processed response: Because the ocean has an enormous thermal inertia
# Standard Answer: The ocean has a significant thermal inertia, leading to a delayed adjustment in sea level.
#
# Query: How does INCCA contribute to building capacity for managing climate-change-related risks?
# Processed response: a network-based scientifi c programme designed to (a) Assess the drivers Executive Summary and implications of climate change through scientifi c research; (b) Prepare climate change assessments once every two years (greenhouse gas estimations and impact of climate change, associated vulnerabilities and adaptation); (c) Develop decision support systems and (d) Build capacity towards management of climate-change related risks and opportunities
# Standard Answer: : INCCA is designed to build capacity through scientific research, decision support systems, and engagement with knowledge institutions
#
# Query: Which sectors were assessed in India's Initial National Communication to the UNFCCC?
# Processed response: water resources, agriculture, natural ecosystems and forestry, human health, infrastructure and energy
# Standard Answer: Water resources, agriculture, natural ecosystems and forestry, human health, infrastructure, and energy.
#
# Query: What are the key features of INCCA's programs, as shown in Figure ES1?
# Processed response: a) Assess the drivers Executive Summary and implications of climate change through scientifi c research; (b) Prepare climate change assessments once every two years (greenhouse gas estimations and impact of climate change, associated vulnerabilities and adaptation); (c) Develop decision support systems and (d) Build capacity towards management of climate-change related risks and opportunities
# Standard Answer: Assessing drivers and implications of climate change, preparing climate change assessments, developing decision support systems, and building capacity.
#
# Query: What is the role of institutions like ISRO and CSIR in studying climate change in India?
# Processed response: research institutions
# Standard Answer: These institutions, along with others, are working on various studies on climate change in collaboration with the Ministry of Environment and Forests.
#
# Query: How is livestock productivity impacted by climate change in the assessment?
# Processed response: temperature–humidity index (THI), which is related to animal stress
# Standard Answer: The analysis is based on temperature and humidity projections, estimating the temperature–humidity index related to animal stress.
#
# Query: What regions are considered in the assessment for the impact on fisheries?
# Processed response: coastal
# Standard Answer: The impact on coastal fisheries is considered in the Western Ghats, North-Eastern region, and Coastal regions.
#
# Query: What is the baseline period for assessing changes in the 2030s?
# Processed response: 1961 to 1990s
# Standard Answer: The baseline period is the average of 1961 to 1990s, also referred to as the 1970s.
#
# Query: Why is impact assessment research considered a complex challenge?
# Processed response: it includes physical, biological and socio-economic aspects
# Standard Answer: It includes physical, biological, and socio-economic aspects, requiring evolving tools for scientific rigor.
#
# Query: What is the climatological diversity of India and how does it complicate the assessment?
# Processed response: Its • climate is characteristic of the subregional physical features, which also typifi es its very diverse biological reserves and natural resources. Therefore the climate of each region though being very distinctive, also merges seamlessly and hence demarcating these four regions has been diffi cult, as they do not conform to the standard agroclimatic zones or the climatic zones
# Standard Answer: India's diverse climate, characterized by subregional features, challenges region demarcation due to seamless merging
#
# Query: What challenges arise in demarcating the coastal region for assessment purposes?
# Processed response: Uncertainties in modelling and data gaps
# Standard Answer: Defining the coastal zone, covering 5,500km along the mainland and 20,000km along islands, poses a significant challenge
#
# Query: What are the uncertainties in modeling and data gaps highlighted in the assessment?
# Processed response: Inherent uncertainties in the key assumptions
# Standard Answer: Inherent uncertainties include assumptions about future population, socio-economic factors, and technical changes, leading to uncertainties in emissions and modeling processes.
#
# Query: Why is a higher resolution model suggested for capturing regional details in India?
# Processed response: It will be more appropriate for capturing the orography of the Indian region.
# Standard Answer: To capture fine-scale details in specific regions like inner Himalayan valleys, higher resolution models (at least 25km x 25km) are deemed more appropriate.
#
# Query: How do observations from satellite measurements differ from IPCC model projections in terms of sea-level rise?
# Processed response: 80 per cent faster
# Standard Answer: Observations show a faster sea-level rise (3.4 mm/year) than the IPCC model projection (1.9 mm/year), attributed to the response of continental ice to greenhouse warming.
#
# Query: What limitations are associated with the InfoCrop model used for assessing agriculture productivity?
# Processed response: pests and disease scenarios are not integrated
# Standard Answer: The model doesn't consider socio-economic trends, technological improvements, and pests/disease scenarios, impacting the comprehensive assessment of agriculture.
#
# Query: Why does the IBIS model used for assessing changes in vegetation require a long-term observational plan?
# Processed response: Because the vegetation changes every few kilometers
# Standard Answer: The model's accuracy is limited due to the lack of an extensive finely gridded database on soil, water, climate, and vegetation types.
# Enter your query (or type 'process' to process the queries):  What challenges are associated with the SWAT model used for assessing water yields in various regions?
# Enter the standard answer for this query:  Challenges include obtaining information from global sources, assuming static man-made changes, and the need for scenario projections reflecting realistic trends.
# Enter your query (or type 'process' to process the queries):  How is the entire Indian region climatologically divided in the assessment?
# Enter the standard answer for this query:  It is divided into the western Himalayas, north-west, north-east, northern-central region, eastern coast, western coast, and the interior plateau.
# Enter your query (or type 'process' to process the queries):  What is the projected rise in annual mean surface air temperature in the 2030s?
# Enter the standard answer for this query:  The annual mean surface air temperature is projected to rise by 1.7°C to 2.0°C in the 2030s
# Enter your query (or type 'process' to process the queries):  How does temperature variability differ across seasons in the 2030s projections?
# Enter the standard answer for this query:  Seasons may be warmer by around 2.0°C, with more variability in winter months towards the 2030s
# Enter your query (or type 'process' to process the queries):  What is the projected increase in mean annual temperature for the Himalayan region in the 2030s?
# Enter the standard answer for this query:  The mean annual temperature in the Himalayan region is projected to increase from 0.9°C to 2.6°C in the 2030s
# Enter your query (or type 'process' to process the queries):  How does the mean annual temperature change in the North-Eastern region in the 2030s?
# Enter the standard answer for this query:  The mean annual temperature in the North-Eastern region is projected to rise from 25.8°C to 26.8°C in the 2030s.
# Enter your query (or type 'process' to process the queries):  What temperature changes are projected for the Western Ghats in the 2030s?
# Enter the standard answer for this query:  Mean annual temperatures in the Western Ghats are likely to increase to 26.8°C–27.5°C in the 2030s
# Enter your query (or type 'process' to process the queries):  How is the coastal region affected in terms of mean annual air temperature in the 2030s?
# Enter the standard answer for this query:  In the eastern coastal region, mean annual air temperature is likely to rise from 28.7°C to 29.3°C in the 2030s
# Enter your query (or type 'process' to process the queries):  What challenges arise in demarcating the coastal region for assessment purposes?
# Enter the standard answer for this query:  Defining the coastal zone, covering 5,500km along the mainland and 20,000km along islands, poses a significant challenge.
# Enter your query (or type 'process' to process the queries):  How does the assessment address uncertainties in modeling assumptions about population and socio-economic factors?
# Enter the standard answer for this query:  Climate projections account for a range of emissions scenarios and the uncertainty in relationships between population, socio-economic development, and technical changes
# Enter your query (or type 'process' to process the queries):  Why is a higher resolution model suggested for capturing regional details in India?
# Enter the standard answer for this query:  To capture fine-scale details in specific regions like inner Himalayan valleys, higher resolution models (at least 25km x 25km) are deemed more appropriate
# Enter your query (or type 'process' to process the queries):  How does temperature variability differ across seasons in the 2030s projections? Answer: Seasons may be warmer by around 2.0°C, with more variability in winter months towards the 2030s.
# Enter the standard answer for this query:  Seasons may be warmer by around 2.0°C, with more variability in winter months towards the 2030s.
# Enter your query (or type 'process' to process the queries):  What is the projected increase in mean annual temperature for the Himalayan region in the 2030s?
# Enter the standard answer for this query:  The mean annual temperature in the Himalayan region is projected to increase from 0.9°C to 2.6°C in the 2030s
# Enter your query (or type 'process' to process the queries):  What challenges are highlighted in using the IBIS model for assessing changes in vegetation in the 2030s?
# Enter the standard answer for this query:  The model requires an extensive finely gridded database on soil, water, and climate parameters, which is challenging to assemble.
# Enter your query (or type 'process' to process the queries):  How does the SWAT model used for assessing water yields handle the absence of nationally generated data?
# Enter the standard answer for this query:  Global sources are used for terrain, soil profile, and land use information, introducing potential limitations in the absence of national data.
# Enter your query (or type 'process' to process the queries):  How can state-specific climate change action plans contribute to overall climate resilience in India?
# Enter the standard answer for this query:  State-specific action plans address local vulnerabilities, enhancing overall climate resilience and adaptive capacity.
# Enter your query (or type 'process' to process the queries):  Why is it essential to focus on state-level assessments for developing climate change action plans in India?
# Enter the standard answer for this query:  State-level assessments provide tailored insights for developing specific action plans, considering the unique climate challenges of each state.
# Enter your query (or type 'process' to process the queries):  Why is it essential to focus on state-level assessments for developing climate change action plans in India?
# Enter the standard answer for this query:  State-level assessments provide tailored insights for developing specific action plans, considering the unique climate challenges of each state.
# Enter your query (or type 'process' to process the queries):  What is the role of the Forest Survey of India (FSI) in addressing the data gap related to forest observation plots?
# Enter the standard answer for this query:  FSI is making efforts to revive forest observation plots, which are crucial for gathering data on vegetation types and soil characteristics.
# Enter your query (or type 'process' to process the queries):  How does the reduction in water yield in the western coastal region compare to the increase in specific areas?
# Processing 19 queries...
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (623 > 512). Running this sequence through the model will result in indexing errors
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Query: What challenges are associated with the SWAT model used for assessing water yields in various regions?
# Processed response: not enough information
# Standard Answer: Challenges include obtaining information from global sources, assuming static man-made changes, and the need for scenario projections reflecting realistic trends.
#
# Query: How is the entire Indian region climatologically divided in the assessment?
# Processed response: western Himalayas, north-west, north-east, northern-central region, eastern coast, western coast, and the interior plateau
# Standard Answer: It is divided into the western Himalayas, north-west, north-east, northern-central region, eastern coast, western coast, and the interior plateau.
#
# Query: What is the projected rise in annual mean surface air temperature in the 2030s?
# Processed response: 1.7°C and 2.0°C
# Standard Answer: The annual mean surface air temperature is projected to rise by 1.7°C to 2.0°C in the 2030s
#
# Query: How does temperature variability differ across seasons in the 2030s projections?
# Processed response: more in winter months
# Standard Answer: Seasons may be warmer by around 2.0°C, with more variability in winter months towards the 2030s
#
# Query: What is the projected increase in mean annual temperature for the Himalayan region in the 2030s?
# Processed response: 2.60.7oC
# Standard Answer: The mean annual temperature in the Himalayan region is projected to increase from 0.9°C to 2.6°C in the 2030s
#
# Query: How does the mean annual temperature change in the North-Eastern region in the 2030s?
# Processed response: rise by 25.80.8 oC to 26.80.9oC
# Standard Answer: The mean annual temperature in the North-Eastern region is projected to rise from 25.8°C to 26.8°C in the 2030s.
#
# Query: What temperature changes are projected for the Western Ghats in the 2030s?
# Processed response: increase to 26.80.4 oC–27.50.4oC
# Standard Answer: Mean annual temperatures in the Western Ghats are likely to increase to 26.8°C–27.5°C in the 2030s
#
# Query: How is the coastal region affected in terms of mean annual air temperature in the 2030s?
# Processed response: In the eastern coastal region, the mean annual air temperature is likely to rise from 28.7 0.6 oC to 29.30.7oC
# Standard Answer: In the eastern coastal region, mean annual air temperature is likely to rise from 28.7°C to 29.3°C in the 2030s
#
# Query: What challenges arise in demarcating the coastal region for assessment purposes?
# Processed response: Uncertainties in modelling and data gaps
# Standard Answer: Defining the coastal zone, covering 5,500km along the mainland and 20,000km along islands, poses a significant challenge.
#
# Query: How does the assessment address uncertainties in modeling assumptions about population and socio-economic factors?
# Processed response: by making climate projections for a range of these SRES emissions scenarios
# Standard Answer: Climate projections account for a range of emissions scenarios and the uncertainty in relationships between population, socio-economic development, and technical changes
#
# Query: Why is a higher resolution model suggested for capturing regional details in India?
# Processed response: It will be more appropriate for capturing the orography of the Indian region.
# Standard Answer: To capture fine-scale details in specific regions like inner Himalayan valleys, higher resolution models (at least 25km x 25km) are deemed more appropriate
#
# Query: How does temperature variability differ across seasons in the 2030s projections? Answer: Seasons may be warmer by around 2.0°C, with more variability in winter months towards the 2030s.
# Processed response: Seasons may be warmer by around 2.0°C, with more variability in winter months towards the 2030s.
# Standard Answer: Seasons may be warmer by around 2.0°C, with more variability in winter months towards the 2030s.
#
# Query: What is the projected increase in mean annual temperature for the Himalayan region in the 2030s?
# Processed response: 2.60.7oC
# Standard Answer: The mean annual temperature in the Himalayan region is projected to increase from 0.9°C to 2.6°C in the 2030s
#
# Query: What challenges are highlighted in using the IBIS model for assessing changes in vegetation in the 2030s?
# Processed response: As the full set of input parameters could not be assembled satisfactorily at even one of the locations, exploratory runs were made based on database using a range of default/approximate values
# Standard Answer: The model requires an extensive finely gridded database on soil, water, and climate parameters, which is challenging to assemble.
#
# Query: How does the SWAT model used for assessing water yields handle the absence of nationally generated data?
# Processed response: obtained from global sources
# ...
# Processed response: a mechanism for sharing and accessing this data in formats that can be easily deciphered
# Standard Answer: Efforts are needed to establish an effective mechanism for sharing and accessing climate, ecosystem, water, agriculture, and socio-economic data.
#
# Query: How are floods projected using the SWAT model, and what regions show a significant change in flood magnitudes?
# Processed response: daily outfl ow discharge in each sub-basin
# Standard Answer: Floods, exceeding 99th percentile flow, may increase from 10% to over 30% in various regions, impacting existing infrastructure.
#
# Query: How is the frequency of droughts expected to change, and what index is used to define the drought scenario?
# Processed response: Soil Moisture Defi cit Index (SMDI) between the 1970s and 2030s has been used for defi ning the drought index
# Standard Answer: There is an increase in the severity of drought, especially in the Himalayan region, based on the Soil Moisture Deficit Index (SMDI).
#
# Query: What is the general trend in water yield in the eastern coastal region, and how does it differ from the western coastal region?
# Processed response: reduction in water yield
# Standard Answer: The eastern coastal region shows a reduction in water yield by up to 40%, while the western coastal region varies, with Karnataka showing an increase of 10%–20%.
#
# Query: How does the Western Ghats region exhibit variability in water yield in the 2030s?
# Processed response: The northern portion of the Western Ghats shows a decrease in the water yield, ranging from 10%–50% in the 2030s with respect to the 1970s.
# Standard Answer: The northern part may experience a 10%–50% decrease, the central part an increase of 5%–20%, and the southern part a decrease of up to 10%.
#
# Query: What spatial variability in water yield is observed in the North-Eastern region, and how does it relate to precipitation and evapotranspiration patterns?
# Processed response: The trend in precipitation in the North-Eastern region exhibits considerable spatial variability in water yield in the 2030s but is in line with the projected patterns of precipitation and evapotranspiration
# Standard Answer: Water yield in the North-Eastern region shows spatial variability, with reductions up to 20% in Arunachal Pradesh and increases in Assam and Manipur.
#
# Query: How is water yield expected to change in the Himalayan region, and what factors contribute to this change?
# Processed response: increase in precipitation
# Standard Answer: Water yield in the Himalayan region is likely to increase by 5%–20%, influenced by precipitation, evapotranspiration, and soil characteristics.
#
# Query: the Coastal regions, what changes are projected for malaria transmission, especially in terms of the number of months open for transmission?
# Processed response: reduction in the number of months open for transmission
# Standard Answer: Malaria transmission in coastal areas may experience a 34% reduction in the number of months open for transmission.
#
# Query: What is the projection for malaria transmission in the Western Ghats, and how does it compare to the current scenario?
# Processed response: no change with respect to current scenario and likely to remain open for 10–12 months in a year
# Standard Answer: Malaria transmission in the Western Ghats is expected to remain unchanged, open for 10–12 months in a year.
#
# Query: How does the transmission of malaria change in the North-Eastern region, and what factors contribute to this change?
# Processed response: There is a likelihood that the windows of transmission of malaria may increasingly remain open for at least 7–9 months and may even remain open for a larger number of months (10–12 months) in a year
# Standard Answer: Malaria transmission windows may increase for 7–9 months, possibly up to 10–12 months, influenced by high relative humidity.
#
# Query: What is the conclusion regarding malaria transmission windows in the Himalayan region based on temperature and humidity projections?
# Processed response: do not match with the observations made
# Standard Answer: Malaria transmission windows are projected to increase in Jammu and Kashmir but remain open for 0–2 months in the 2030s
#
# Query: How does climate change impact human health in the studied regions?
# Processed response: changes in extreme temperatures, fl ooding due to extreme precipitation, melting of glaciers, and sea level rise
# Standard Answer: Morbidity and mortality are likely to increase due to direct effects like heat stress and indirect effects such as vector-borne diseases.
#
# Query: How does the frequency of rainy days change in the Western Ghats, especially in the Karnataka region?
# Processed response: There may be an increase in rainfall in the range of 1-5 days
# Standard Answer: The number of rainy days may decrease, but intensity is likely to increase by 1–2mm/day, with variations in Karnataka.
#
# Query: How does the THI impact livestock productivity in the North-Eastern region, and during which months is it likely to be highest?
# Processed response: April–October
# Standard Answer: THI is likely to increase, leading to severe thermal discomfort of livestock, especially during April–October in the 2030s.
#
# Query: What is the projected change in annual temperature in the Western Ghats, North-Eastern region, and Coastal region in the 2030s?
# Processed response: Coastal region
# Standard Answer: Annual mean surface air temperature is projected to rise by 1.7°C to 2.0°C in the 2030s in these regions.
#
# Query: In the Himalayan region, what percentage of forest grids is projected to undergo change in the 2030s, and what is the expected change in Net Primary Productivity (NPP)?
# Processed response: 56% of the grids are projected to undergo change in the 2030s, and the Net Primary Productivity (NPP) is projected to increase in the region by about 57% on an average by the 2030s
# Standard Answer: About 56% of forest grids may undergo change, with an average projected increase in NPP of about 57% in the Himalayan region.
#
# Query: How has the temperature trend affected apple production in the Himachal Pradesh region, and what months experience the most significant decline in chilling hours?
# Processed response: Apple production in the Himachal Pradesh region has decreased between 1982 and 2005 as the increase in maximum temperature has led to a reduction in total chilling hours in the region—a decline of more than 9.1 units per year in last 23 years has taken place
# Standard Answer: Increasing temperatures led to a decline in apple production, especially during the months of November and February
#
# Query: What is the projected impact of climate change on maize and sorghum yields in the Coastal region, both irrigated and rain-fed?
# Processed response: loss between 15% and 50%
# Standard Answer: Climate change is likely to reduce yields of irrigated maize by 15% to 50%, and rain-fed maize by up to 35%.
# Enter your query (or type 'process' to process the queries):  How does the intensity of extreme precipitation events change in the Coastal region, and what areas might experience an increase in rainfall?
# Enter the standard answer for this query:  Rainy days may decrease by 1–5 days, but intensity is likely to increase between 1mm/day and 4mm/day, with slight increases along the Orissa coast.
# Enter your query (or type 'process' to process the queries):  What is the expected change in extreme temperatures in the Coastal region, and how do minimum and maximum temperatures differ
# Enter the standard answer for this query:  Minimum temperatures may rise by 2.0°C to 4.5°C, and maximum temperatures may increase by 1°C to 3.5°C in the Coastal region.
# Enter your query (or type 'process' to process the queries):  How is the number of rainy days and intensity expected to change in the Western Ghats, especially in the Karnataka region?
# Enter the standard answer for this query:  In the Western Ghats, the number of rainy days may decrease, but intensity is likely to increase by 1–2mm/day, with variations in Karnataka.
# Enter your query (or type 'process' to process the queries):  What are the observed trends in the recruitment and catches of oil sardines along the coastal region, and what factors influence them?
# Enter the standard answer for this query:  Oil sardine recruitment and catches may increase due to warming, elevated Sea Surface Temperature (SST), and favorable wind conditions
# Enter your query (or type 'process' to process the queries):  Why is it necessary to develop a primary database on farm inputs applied by farmers on a fine-gridded level?
# Enter the standard answer for this query:  A finely gridded database is necessary to improve the accuracy of simulation analysis, especially when assessing agriculture at a district level.
# Enter your query (or type 'process' to process the queries):  Why is a scenario projection required for assessing man-made changes in water availability?
# Enter the standard answer for this query:  Scenario projections can realistically capture trends in man-made changes like dams and diversions, which may not remain static in the future.
# Enter your query (or type 'process' to process the queries):  Why does the InfoCrop model exclude considerations of socio-economic trends in agriculture?
# Enter the standard answer for this query:  The model focuses on climate impacts and lacks integration of socio-economic factors like technological improvements and market demand
# Enter your query (or type 'process' to process the queries):  Why are semi-empirical estimates of sea-level rise considered more accurate in some studies?
# Enter the standard answer for this query:  Semi-empirical estimates are based on the proportional relationship between global warming and the rate of sea-level rise, incorporating observed data.
# Enter your query (or type 'process' to process the queries):  Why is a higher resolution model recommended for detailed projections in specific regions like the Western Ghats?
# Enter the standard answer for this query:  The PRECIS model at 50km resolution is suitable for broad regions, but higher resolution (at least 25km x 25km) is necessary for detailed projections.
# Enter your query (or type 'process' to process the queries):  process
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Query: How does the intensity of extreme precipitation events change in the Coastal region, and what areas might experience an increase in rainfall?
# Processed response: The intensity of rainfall is likely to increase between 1mm/day and 4mm/day
# Standard Answer: Rainy days may decrease by 1–5 days, but intensity is likely to increase between 1mm/day and 4mm/day, with slight increases along the Orissa coast.
#
# Query: What is the expected change in extreme temperatures in the Coastal region, and how do minimum and maximum temperatures differ
# Processed response: The warming in night temperatures is more over the south peninsula and central and northern India, whereas daytime warming is more in central and northern India
# Standard Answer: Minimum temperatures may rise by 2.0°C to 4.5°C, and maximum temperatures may increase by 1°C to 3.5°C in the Coastal region.
#
# Query: How is the number of rainy days and intensity expected to change in the Western Ghats, especially in the Karnataka region?
# Processed response: The intensity of rainfall is likely to increase by 1–2mm/day
# Standard Answer: In the Western Ghats, the number of rainy days may decrease, but intensity is likely to increase by 1–2mm/day, with variations in Karnataka.
#
# Query: What are the observed trends in the recruitment and catches of oil sardines along the coastal region, and what factors influence them?
# Processed response: An increase in recruitment and catches of oil sardine during the post-southwest monsoon season along the coastal region, especially along the Kerala coast, is expected in the future due to warming, elevated Sea Surface Temperature (SST), favourable wind (and perhaps current) and increasing Coastal Upwelling Index (CUI) inducing higher chlorophyll-a concentration during the southwest
# Standard Answer: Oil sardine recruitment and catches may increase due to warming, elevated Sea Surface Temperature (SST), and favorable wind conditions
#
# Query: Why is it necessary to develop a primary database on farm inputs applied by farmers on a fine-gridded level?
# Processed response: To overcome the limitation of the model
# Standard Answer: A finely gridded database is necessary to improve the accuracy of simulation analysis, especially when assessing agriculture at a district level.
#
# Query: Why is a scenario projection required for assessing man-made changes in water availability?
# Processed response: b).
# Standard Answer: Scenario projections can realistically capture trends in man-made changes like dams and diversions, which may not remain static in the future.
#
# Query: Why does the InfoCrop model exclude considerations of socio-economic trends in agriculture?
# Processed response: lack of proper scientifi c data
# Standard Answer: The model focuses on climate impacts and lacks integration of socio-economic factors like technological improvements and market demand
#
# Query: Why are semi-empirical estimates of sea-level rise considered more accurate in some studies?
# Processed response: Because of the limitations of the physical climate models used by the IPCC
# Standard Answer: Semi-empirical estimates are based on the proportional relationship between global warming and the rate of sea-level rise, incorporating observed data.
#
# Query: Why is a higher resolution model recommended for detailed projections in specific regions like the Western Ghats?
# Processed response: capturing the orography of the Indian region
# Standard Answer: The PRECIS model at 50km resolution is suitable for broad regions, but higher resolution (at least 25km x 25km) is necessary for detailed projections.
# Enter your query (or type 'process' to process the queries):  exit
# Excel file saved at /kaggle/working/queries_and_responses.xlsx. Exiting.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Define a function to calculate cosine similarity between two texts
def calculate_cosine_similarity(text1, text2):
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform([text1, text2])
    return cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]

# Read the Excel file
file_path = '/kaggle/input/queries-and-responses/queries_and_responses.xlsx'  # Update the path accordingly
df = pd.read_excel(file_path)

# Calculate similarities
df['Similarity'] = df.apply(lambda row: calculate_cosine_similarity(row['Response'], row['Standard Answer']), axis=1)

# Print similarities (optional)
print(df[['Response', 'Standard Answer', 'Similarity']])

# Save the updated DataFrame back to an Excel file
output_file_path = '/kaggle/working/queries_and_responses_with_similarity.xlsx'
df.to_excel(output_file_path, index=False)

print(f"Updated Excel file saved at {output_file_path}.")
# Out:
#                                               Response  \
# 0    to assess the drivers and implications of clim...
# 1                                          unequivocal
# 2    Agriculture, Water, Natural Ecosystems and Bio...
# 3    the Himalayan region, the North-Eastern region...
# 4    MoEF , Ministry of Earth Sciences, Ministry of...
# ..                                                 ...
# 99             To overcome the limitation of the model
# 100                                                b).
# 101                    lack of proper scientifi c data
# 102  Because of the limitations of the physical cli...
# 103       capturing the orography of the Indian region
#
#                                        Standard Answer  Similarity
# 0    To assess the drivers and implications of clim...    0.763310
# 1    The impact of human activities on climate is u...    0.219511
# 2    Water resources, agriculture, natural ecosyste...    0.682989
# 3    Himalayan region, North-Eastern region, Wester...    0.579739
# 4    Various ministries, research institutions, and...    0.411131
# ..                                                 ...         ...
# 99   A finely gridded database is necessary to impr...    0.196898
# 100  Scenario projections can realistically capture...    0.000000
# 101  The model focuses on climate impacts and lacks...    0.052663
# 102  Semi-empirical estimates are based on the prop...    0.228570
# 103  The PRECIS model at 50km resolution is suitabl...    0.067001
#
# [104 rows x 3 columns]
# Updated Excel file saved at /kaggle/working/queries_and_responses_with_similarity.xlsx.
